# %%
import pandas as pd

# %%
ene = pd.read_csv('2019-01.csv', low_memory = False)
feb = pd.read_csv('2019-02.csv', low_memory = False)
mar = pd.read_csv('2019-03.csv', low_memory = False)
abr = pd.read_csv('2019-04.csv', low_memory = False)
may = pd.read_csv('2019-05.csv', low_memory = False)
jun = pd.read_csv('2019-06.csv', low_memory = False)
jul = pd.read_csv('2019-07.csv', low_memory = False)
ago = pd.read_csv('2019-08.csv', low_memory = False)
sep = pd.read_csv('2019-09.csv', low_memory = False)

# %%
ene.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 697289 entries, 0 to 697288
# Data columns (total 9 columns):
# Genero_Usuario           697289 non-null object
# Edad_Usuario             697289 non-null int64
# Bici                     697289 non-null object
# Ciclo_Estacion_Retiro    697289 non-null int64
# Fecha_Retiro             697289 non-null object
# Hora_Retiro              697289 non-null object
# Ciclo_Estacion_Arribo    697289 non-null int64
# Fecha_Arribo             697289 non-null object
# Hora_Arribo              697289 non-null object
# dtypes: int64(3), object(6)
# memory usage: 47.9+ MB

# %%
feb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 684077 entries, 0 to 684076
# Data columns (total 9 columns):
# Genero_Usuario           684077 non-null object
# Edad_Usuario             684077 non-null int64
# Bici                     684077 non-null object
# Ciclo_Estacion_Retiro    684077 non-null int64
# Fecha_Retiro             684077 non-null object
# Hora_Retiro              684077 non-null object
# Ciclo_Estacion_Arribo    684077 non-null int64
# Fecha_Arribo             684077 non-null object
# Hora_Arribo              684077 non-null object
# dtypes: int64(3), object(6)
# memory usage: 47.0+ MB

# %%
mar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 752299 entries, 0 to 752298
# Data columns (total 10 columns):
# Genero_Usuario           752299 non-null object
# Edad_Usuario             752299 non-null int64
# Bici                     752299 non-null object
# Ciclo_Estacion_Retiro    752299 non-null int64
# Fecha_Retiro             752299 non-null object
# Hora_Retiro              752299 non-null object
# Ciclo_Estacion_Arribo    752299 non-null object
# Fecha_Arribo             752299 non-null object
# Hora_Arribo              752299 non-null object
# Unnamed: 9               1 non-null object
# dtypes: int64(2), object(8)
# memory usage: 57.4+ MB

# %%
ene["Mes"] = ene.Fecha_Retiro.str.slice(start = 3, stop = 5)
feb["Mes"] = feb.Fecha_Retiro.str.slice(start = 3, stop = 5)
mar["Mes"] = mar.Fecha_Retiro.str.slice(start = 3, stop = 5)
abr["Mes"] = abr.Fecha_Retiro.str.slice(start = 3, stop = 5)
may["Mes"] = may.Fecha_Retiro.str.slice(start = 3, stop = 5)
jun["Mes"] = jun.Fecha_Retiro.str.slice(start = 3, stop = 5)
jul["Mes"] = jul.Fecha_Retiro.str.slice(start = 3, stop = 5)
ago["Mes"] = ago.Fecha_Retiro.str.slice(start = 3, stop = 5)
sep["Mes"] = sep.Fecha_Retiro.str.slice(start = 3, stop = 5)

# %%
mar
# Out:
#        Genero_Usuario  Edad_Usuario   Bici  Ciclo_Estacion_Retiro  \
# 0                   M            34   8861                    143
# 1                   F            33   2601                     51
# 2                   M            25   8257                    340
# 3                   M            32  15007                    139
# 4                   F            22   7601                     81
# ...               ...           ...    ...                    ...
# 752294              M            36  11045                    150
# 752295              M            30   3669                    150
# 752296              M            33   1515                     53
# 752297              M            28   9616                     45
# 752298              M            42   9935                     10
#
#        Fecha_Retiro Hora_Retiro Ciclo_Estacion_Arribo Fecha_Arribo  \
# 0        01/03/2019    00:00:54                    68   01/03/2019
# ...

# %%
mar.loc[mar["Unnamed: 9"].isna() == False]
# Out:
#        Genero_Usuario  Edad_Usuario  Bici  Ciclo_Estacion_Retiro Fecha_Retiro  \
# 113432              M            44  9944                    267   06/03/2019
#
#        Hora_Retiro Ciclo_Estacion_Arribo Fecha_Arribo Hora_Arribo Unnamed: 9  \
# 113432    08:06:23               32:11.8           10    00:00:00   08:41:11
#
#        Mes
# 113432  03

# %%
mar = mar.drop(113432, axis = 0)

# %%
mar = mar.reset_index(drop = True)

# %%
mar = mar.dropna(axis = 1)

# %%
mar
# Out:
#        Genero_Usuario  Edad_Usuario   Bici  Ciclo_Estacion_Retiro  \
# 0                   M            34   8861                    143
# 1                   F            33   2601                     51
# 2                   M            25   8257                    340
# 3                   M            32  15007                    139
# 4                   F            22   7601                     81
# ...               ...           ...    ...                    ...
# 752293              M            36  11045                    150
# 752294              M            30   3669                    150
# 752295              M            33   1515                     53
# 752296              M            28   9616                     45
# 752297              M            42   9935                     10
#
#        Fecha_Retiro Hora_Retiro Ciclo_Estacion_Arribo Fecha_Arribo  \
# 0        01/03/2019    00:00:54                    68   01/03/2019
# ...

# %%
general_data = pd.DataFrame()

# %%
general_data = general_data.append(ene, ignore_index = True)
general_data = general_data.append(feb, ignore_index = True)
general_data = general_data.append(mar, ignore_index = True)
general_data = general_data.append(abr, ignore_index = True)
general_data = general_data.append(may, ignore_index = True)
general_data = general_data.append(jun, ignore_index = True)
general_data = general_data.append(jul, ignore_index = True)
general_data = general_data.append(ago, ignore_index = True)
general_data = general_data.append(sep, ignore_index = True)

# %%
general_data
# Out:
#         Genero_Usuario  Edad_Usuario   Bici  Ciclo_Estacion_Retiro  \
# 0                    M            36  11444                     67
# 1                    M            36   9196                     55
# 2                    M            38   2612                     29
# 3                    M            43   7463                     29
# 4                    M            37   3987                    136
# ...                ...           ...    ...                    ...
# 6396084              M            32  11581                    121
# 6396085              M            30   8676                    291
# 6396086              F            47  11748                    110
# 6396087              M            35   9095                    110
# 6396088              M            25   8341                     15
#
#         Fecha_Retiro Hora_Retiro Ciclo_Estacion_Arribo Fecha_Arribo  \
# 0         01/01/2019     0:08:44                    36   01/01/2019
# ...

# %%
general_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6396089 entries, 0 to 6396088
# Data columns (total 10 columns):
# Genero_Usuario           object
# Edad_Usuario             int64
# Bici                     object
# Ciclo_Estacion_Retiro    int64
# Fecha_Retiro             object
# Hora_Retiro              object
# Ciclo_Estacion_Arribo    object
# Fecha_Arribo             object
# Hora_Arribo              object
# Mes                      object
# dtypes: int64(2), object(8)
# memory usage: 488.0+ MB

# %%
general_data.Ciclo_Estacion_Arribo = general_data.Ciclo_Estacion_Arribo.astype(int)

# %%
general_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6396089 entries, 0 to 6396088
# Data columns (total 10 columns):
# Genero_Usuario           object
# Edad_Usuario             int64
# Bici                     object
# Ciclo_Estacion_Retiro    int64
# Fecha_Retiro             object
# Hora_Retiro              object
# Ciclo_Estacion_Arribo    int32
# Fecha_Arribo             object
# Hora_Arribo              object
# Mes                      object
# dtypes: int32(1), int64(2), object(7)
# memory usage: 463.6+ MB

# %%
general_data.to_csv("data.csv")
